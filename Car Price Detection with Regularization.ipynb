# %%
# Importing Necesary Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Opening Excel file
df =pd.read_excel('car_data.xlsx ')

# %%
# Showing Data
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# Checking Nulls and Data Type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# Checking min,max,count,mean etc.. of all columns
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
# Cheking sum of null if any
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# Checkin percentage of nulls
(df.isnull().sum()/len(df))*100
# Out:
# Car_Name         0.0
# Year             0.0
# Selling_Price    0.0
# Present_Price    0.0
# Kms_Driven       0.0
# Fuel_Type        0.0
# Seller_Type      0.0
# Transmission     0.0
# Owner            0.0
# dtype: float64

# %%
# Checking unique values of column'Year'
df['Year'].unique()
# Out:
# array([2014, 2013, 2017, 2011, 2018, 2015, 2016, 2009, 2010, 2012, 2003,
#        2008, 2006, 2005, 2004, 2007], dtype=int64)

# %%
# Checking unique values of column'Price'
df['Present_Price'].unique()
# Out:
# array([ 5.59 ,  9.54 ,  9.85 ,  4.15 ,  6.87 ,  9.83 ,  8.12 ,  8.61 ,
#         8.89 ,  8.92 ,  3.6  , 10.38 ,  9.94 ,  7.71 ,  7.21 , 10.79 ,
#         5.09 ,  7.98 ,  3.95 ,  5.71 ,  8.01 ,  3.46 ,  4.41 ,  4.99 ,
#         5.87 ,  6.49 ,  5.98 ,  4.89 ,  7.49 ,  9.95 ,  8.06 ,  7.74 ,
#         7.2  ,  2.28 ,  3.76 ,  7.87 ,  3.98 ,  7.15 ,  2.69 , 12.04 ,
#         9.29 , 30.61 , 19.77 , 10.21 , 15.04 ,  7.27 , 18.54 ,  6.8  ,
#        35.96 , 18.61 ,  7.7  , 36.23 ,  6.95 , 23.15 , 20.45 , 13.74 ,
#        20.91 ,  6.76 , 12.48 ,  8.93 , 14.68 , 12.35 , 22.83 , 14.89 ,
#         7.85 , 25.39 , 13.46 , 23.73 , 92.6  ,  6.05 , 16.09 , 13.7  ,
#        22.78 , 18.64 ,  1.9  ,  1.82 ,  1.78 ,  1.6  ,  1.47 ,  2.37 ,
#         3.45 ,  1.5  ,  2.4  ,  1.4  ,  1.26 ,  1.17 ,  1.75 ,  0.95 ,
#         0.8  ,  0.87 ,  0.84 ,  0.82 ,  0.81 ,  0.74 ,  1.2  ,  0.787,
#         0.99 ,  0.94 ,  0.826,  0.55 ,  0.88 ,  0.51 ,  0.52 ,  0.54 ,
# ...

# %%
df['Selling_Price'].unique()
# Out:
# array([ 3.35,  4.75,  7.25,  2.85,  4.6 ,  9.25,  6.75,  6.5 ,  8.75,
#         7.45,  6.85,  7.5 ,  6.1 ,  2.25,  7.75,  3.25,  2.65,  4.9 ,
#         4.4 ,  2.5 ,  2.9 ,  3.  ,  4.15,  6.  ,  1.95,  3.1 ,  2.35,
#         4.95,  5.5 ,  2.95,  4.65,  0.35,  5.85,  2.55,  1.25,  1.05,
#         5.8 , 14.9 , 23.  , 18.  , 16.  ,  2.75,  3.6 ,  4.5 ,  4.1 ,
#        19.99,  6.95, 18.75, 23.5 , 33.  , 19.75,  4.35, 14.25,  3.95,
#         1.5 ,  5.25, 14.5 , 14.73, 12.5 ,  3.49, 35.  ,  5.9 ,  3.45,
#         3.8 , 11.25,  3.51,  4.  , 20.75, 17.  ,  7.05,  9.65,  1.75,
#         1.7 ,  1.65,  1.45,  1.35,  1.2 ,  1.15,  1.11,  1.1 ,  1.  ,
#         0.95,  0.9 ,  0.75,  0.8 ,  0.78,  0.72,  0.65,  0.6 ,  0.55,
#         0.52,  0.51,  0.5 ,  0.48,  0.45,  0.42,  0.4 ,  0.38,  0.31,
#         0.3 ,  0.27,  0.25,  0.2 ,  0.18,  0.17,  0.16,  0.15,  0.12,
#         0.1 ,  5.75,  5.15,  7.9 ,  4.85, 11.75,  3.15,  6.45,  3.5 ,
# ...

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df['Owner'].unique()
# Out:
# array([0, 1, 3], dtype=int64)

# %%
df['Kms_Driven'].unique()
# Out:
# array([ 27000,  43000,   6900,   5200,  42450,   2071,  18796,  33429,
#         20273,  42367,   2135,  51000,  15000,  26000,  77427,  41678,
#         35500,  41442,  25000,   2400,  50000,  45280,  56879,  20000,
#         55138,  16200,  44542,  45000,  51439,  54200,  39000,  49998,
#         48767, 127000,  10079,  62000,  24524,  46706,  58000,  45780,
#         64532,  65000,  25870,  37000, 104707,  40000, 135000,  90000,
#         70000,  40534,  39485,  41000,  40001,  40588,  78000,  47000,
#          6000,  11000,  59000,  88000,  12000,  71000,  56001,  83000,
#         36000,  72000, 135154,  80000,  89000,  23000,  38000, 197176,
#        142000,  56000,  58242,  75000,  29000,   8700,  50024,   3000,
#          1400,   4000,   1200,   4100,  21700,  16500,  18000,   7000,
#         35000,  17000,  17500,  33000,  14000,   5400,   5700,  46500,
#         11500,   1300,   5000,   3500,    500,  11800,  23500,  16000,
# ...

# %%
df['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis', 800,
#        'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
#        'Yamaha FZ  v 2.0', 'Bajaj Pulsar  NS 200', 'Bajaj Pulsar 220 F',
# ...

# %% [markdown]
# # PERFORMING EDA

# %%
# Splitting column 'car_name' and taking only first 4 words of it
df['Car_Name']= df['Car_Name'].str.split(' ').str.slice(0,5).str.join(' ')

# %%
df['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis', nan,
#        'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
#        'Yamaha FZ  v 2.0', 'Bajaj Pulsar  NS 200', 'Bajaj Pulsar 220 F',
# ...

# %%
sns.countplot(data=df,x='Seller_Type')
plt.show()

# %%
sns.barplot(data=df,y='Seller_Type',x='Selling_Price')
plt.show()

# %%
sns.countplot(data=df,x='Fuel_Type')
plt.show()

# %%
sns.barplot(data=df,y='Fuel_Type',x='Selling_Price')
plt.show()

# %%
sns.countplot(data=df,x='Transmission')
plt.show()

# %%
sns.barplot(data=df,y='Transmission',x='Selling_Price')
plt.show()

# %%
# Showing lmplot plot between car selling price and car kms driven
sns.lmplot(data=df,x='Kms_Driven',y='Selling_Price')
plt.show()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# count of car by unique car name
car_count=df['Car_Name'].value_counts()

plt.figure(figsize=(15,5))
car_count.plot(kind='bar',color='skyblue')
plt.title('Distriution of Car Name')
plt.xlabel('Car Name')
plt.ylabel('Count')
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.show()

# %%
# Grouping car name and aggregrating other columns
df_car=df.groupby('Car_Name').agg({'Selling_Price':'mean','Present_Price':'mean','Kms_Driven':'mean'}).reset_index()

# %%
df_car
# Out:
#                     Car_Name  Selling_Price  Present_Price     Kms_Driven
# 0                  Activa 3g       0.310000       0.530000  250250.000000
# 1                  Activa 4g       0.400000       0.510000    1300.000000
# 2              Bajaj  ct 100       0.180000       0.320000   35000.000000
# 3          Bajaj Avenger 150       0.750000       0.800000    7000.000000
# 4   Bajaj Avenger 150 street       0.600000       0.800000   20000.000000
# ..                       ...            ...            ...            ...
# 92                       sx4       3.158333       8.066667   50740.000000
# 93                     verna       6.107857       9.400000   42747.285714
# 94             vitara brezza       9.250000       9.830000    2071.000000
# 95                   wagon r       2.512500       4.450000   40644.750000
# 96                     xcent       4.966667       7.130000   27448.333333
#
# [97 rows x 4 columns]

# %%
# Removing outliers from prediction column 'selling price'
sns.boxplot(data=df,x='Selling_Price')
plt.show()

# %%
# Sorting Selling price of car by descending order
df=df.sort_values(by='Selling_Price',ascending=False).reset_index()

# %%
df.head()
# Out:
#    index      Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0     86  land cruiser  2010           35.0          92.60       78000
# 1     64      fortuner  2017           33.0          36.23        6000
# 2     63      fortuner  2015           23.5          35.96       47000
# 3     82        innova  2017           23.0          25.39       15000
# 4     51      fortuner  2015           23.0          30.61       40000
#
#   Fuel_Type Seller_Type Transmission  Owner
# 0    Diesel      Dealer       Manual      0
# 1    Diesel      Dealer    Automatic      0
# 2    Diesel      Dealer    Automatic      0
# 3    Diesel      Dealer    Automatic      0
# 4    Diesel      Dealer    Automatic      0

# %%
# Removing outliers and and resetting index
df=df[3:].reset_index()

# %%
df.head()
# Out:
#    level_0  index  Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0        3     82    innova  2017          23.00          25.39       15000
# 1        4     51  fortuner  2015          23.00          30.61       40000
# 2        5     93  fortuner  2015          23.00          30.61       40000
# 3        6     96    innova  2016          20.75          25.39       29000
# 4        7     59  fortuner  2014          19.99          35.96       41000
#
#   Fuel_Type Seller_Type Transmission  Owner
# 0    Diesel      Dealer    Automatic      0
# 1    Diesel      Dealer    Automatic      0
# 2    Diesel      Dealer    Automatic      0
# 3    Diesel      Dealer    Automatic      0
# 4    Diesel      Dealer    Automatic      0

# %%
# Dropping extra index'Level 0'
df.drop(['level_0','index'],axis=1)
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0                innova  2017          23.00          25.39       15000
# 1              fortuner  2015          23.00          30.61       40000
# 2              fortuner  2015          23.00          30.61       40000
# 3                innova  2016          20.75          25.39       29000
# 4              fortuner  2014          19.99          35.96       41000
# ..                  ...   ...            ...            ...         ...
# 293           Activa 3g  2008           0.17           0.52      500000
# 294    Honda CB twister  2010           0.16           0.51       33000
# 295  Bajaj Discover 125  2011           0.15           0.57       35000
# 296      Honda CB Shine  2007           0.12           0.58       53000
# 297    Bajaj Pulsar 150  2006           0.10           0.75       92233
#
#     Fuel_Type Seller_Type Transmission  Owner
# 0      Diesel      Dealer    Automatic      0
# ...

# %%
# Splitting data into X and Y variable

# %%
X= df.drop(columns='Selling_Price')
y=df['Selling_Price']

# %%
#Using oneHot encoder for column transformation from 'string' to 'int'
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

categorical_cols=['Car_Name','Fuel_Type','Seller_Type','Transmission']
transformer= ColumnTransformer([('OHE',OneHotEncoder(),categorical_cols)],
                            remainder='passthrough')
X=transformer.fit_transform(X)

# %%
# Spliting the data in train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size= 0.3)

# %%
X_train.shape , X_test.shape
# Out:
# ((208, 110), (90, 110))

# %%
# Appling multiple Linear regression on train and test data
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# predicting the selling price
y_predictions=model.predict(X_test)

# %%
y_predictions
# Out:
# array([ 3.22017285,  1.39681001,  1.97578507,  0.63669876,  0.53647642,
#        -1.95923012,  7.07498186,  4.98121452,  7.33556989,  2.46344341,
#         2.43045613,  5.56606244,  5.81306243, -2.79499105, 20.82869641,
#         4.48402943, 15.68378822, -1.7611807 ,  5.14000928, -0.38853997,
#         0.17245414,  3.13229581, 18.04073322,  1.27513714,  9.49026908,
#         0.96480205,  6.49737243, 17.69218363,  4.05930015,  4.12344847,
#         4.76905059,  5.36623621,  1.61665592,  7.58862312,  5.74328284,
#        11.42188561,  3.11225523,  2.36157262,  2.37227792,  0.22015332,
#         0.68496768, -3.15073608, 18.89317174,  0.45897161, -2.42418844,
#         2.8788503 ,  2.41648979,  9.65162267,  3.61437084,  1.47359133,
#        -2.3594731 ,  0.52252128,  2.90004432,  5.20563807,  7.95831474,
#         5.79295161,  6.72103852,  5.76104625,  2.65938913,  7.07826212,
#         7.42033125,  4.30566572,  2.2038667 , -0.0558292 , -0.7620186 ,
# ...

# %%
# Checking metrics like r2 ,r2 score,mae
from sklearn.metrics import mean_absolute_error,r2_score
MAE= mean_absolute_error(y_test,y_predictions)
R_squared=r2_score(y_test,y_predictions)

n=len(y_test)
p=X_test.shape[1]
Adjusted_R_squared=1-(1-R_squared)*(n-1)/(n-p-1)

# %%
r2_score(y_test,y_predictions)
# Out:
# 0.9129890581379756

# %%
R_squared
# Out:
# 0.9129890581379756

# %%
Adjusted_R_squared
# Out:
# 1.3687606583676273

# %%
MAE
# Out:
# 0.9333271172847203

# %%
from sklearn.metrics import mean_squared_error
MSE=mean_squared_error(y_test,y_predictions)

# %%
MSE
# Out:
# 1.8135082405818126

# %%
residuals= y_test- y_predictions

# %%
residuals
# Out:
# 152    0.229827
# 239   -0.796810
# 208   -0.825785
# 250   -0.136699
# 233    0.113524
#          ...
# 33     0.480898
# 236   -0.462615
# 185    0.865145
# 172    1.095226
# 225   -0.882146
# Name: Selling_Price, Length: 90, dtype: float64

# %%
# Distributions of Residuals
from scipy import stats
plt.figure(figsize=(10,6))
sns.histplot(residuals,kde=True)
plt.title('Distributions of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.show()

# %%
from scipy import stats

plt.figure(figsize=(10,6))
stats.probplot(residuals,dist="norm",plot=plt)
plt.title('Q-Q plot')
plt.xlabel('Theortical Quantiles')
plt.ylabel('Ordered Residuals')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_predictions,residuals,alpha=0.5)
plt.axhline(y=0,color='r',linestyle='--')
plt.title('Resi. plot')
plt.xlabel('Predicted values')
plt.ylabel('RESiduals')
plt.show()

# %% [markdown]
#  # APPLYING REGULARIZATION

# %%
# RIDGE REGULARIZATION(L2 NORM)

# %%
from sklearn.linear_model import Ridge
R=Ridge(alpha=1.0)
R.fit(X_train,y_train)
# Out:
# Ridge()

# %%
y_predict=R.predict(X_test)

# %%
y_predict
# Out:
# array([ 3.20017967,  1.35529804,  1.93392889,  0.60999823,  0.51448265,
#        -1.95856928,  7.04645497,  4.9813342 ,  7.53861723,  2.37789584,
#         2.38145548,  5.61201189,  5.85296377, -2.6668744 , 20.58279123,
#         4.44426063, 15.39295694, -1.64776593,  5.37832536, -0.40712687,
#         0.20976118,  3.15313318, 17.69615416,  1.38042088,  9.49961545,
#         0.93128531,  6.47327028, 17.48995615,  4.03529614,  4.20425646,
#         4.76236916,  5.43479227,  1.53426828,  7.6342706 ,  5.69849612,
#        11.27645999,  3.12717044,  2.39231426,  2.43147044,  0.19521925,
#         0.6277656 , -3.13234896, 18.61619133,  0.60559795, -2.48014929,
#         2.8239404 ,  2.36415062,  9.76657689,  3.69348438,  1.53096645,
#        -2.37418523,  0.49418171,  2.99922086,  5.15581685,  8.16513829,
#         5.7344558 ,  6.63945212,  5.85736853,  2.54085396,  7.12763243,
#         7.57501541,  4.30831041,  2.23061114, -0.04846145, -0.78666045,
# ...

# %%
r2_score(y_test,y_predict)
# Out:
# 0.9151581249717305

# %%
R_squared
# Out:
# 0.9129890581379756

# %%
Adjusted_R_squared
# Out:
# 1.3687606583676273

# %%
MSE=mean_squared_error(y_test,y_predict)

# %%
MSE
# Out:
# 1.7682998967435752

# %%
# Applying Lasso Regularization(L1 norm)

# %%
from sklearn.linear_model import Lasso
L=Lasso(alpha=0.1)
L.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_pred=L.predict(X_test)

# %%
y_pred
# Out:
# array([ 3.57481836,  1.08511191,  1.57327034,  0.34902096,  0.23032223,
#        -2.13179736,  7.06974607,  5.30667975,  9.42519105,  2.51373914,
#         2.01587442,  5.52649883,  5.69379442, -2.03416018, 18.56550843,
#         4.5542191 , 12.73049525, -2.10080139,  7.49695088, -0.59407658,
#         0.14819661,  3.74082551, 14.85923756,  1.10761988,  9.87189974,
#         0.68948645,  6.5829032 , 15.5776109 ,  4.36019937,  5.08014195,
#         5.08327002,  6.20589362,  1.05833908,  7.47499254,  5.63181726,
#         9.95956155,  3.35895192,  2.91294113,  2.62987823, -0.02360377,
#         0.23200516, -3.0746308 , 15.8710427 ,  1.68942979, -2.93529483,
#         2.44295095,  1.99167069,  9.8469902 ,  4.58442772,  2.24025455,
#        -2.64933448,  0.2713265 ,  3.98254177,  5.10338252, 10.02603053,
#         5.70354979,  6.52383178,  5.77621602,  2.23175751,  7.6770493 ,
#         7.84729401,  4.66063632,  2.27045178, -0.18793445, -0.97478008,
# ...

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8809887607371324

# %%
R_squared
# Out:
# 0.9129890581379756

# %%
Adjusted_R_squared
# Out:
# 1.3687606583676273

# %%
MSE=mean_squared_error(y_test,y_pred)

# %%
MSE
# Out:
# 2.480468071099706

# %%
# Applying ElasticNet Regularization(lasso + Ridge)

# %%
from sklearn.linear_model import ElasticNet
NE=ElasticNet(alpha=1.0)
NE.fit(X_train,y_train)
# Out:
# ElasticNet()

# %%
y_preds=L.predict(X_test)

# %%
y_preds
# Out:
# array([ 3.57481836,  1.08511191,  1.57327034,  0.34902096,  0.23032223,
#        -2.13179736,  7.06974607,  5.30667975,  9.42519105,  2.51373914,
#         2.01587442,  5.52649883,  5.69379442, -2.03416018, 18.56550843,
#         4.5542191 , 12.73049525, -2.10080139,  7.49695088, -0.59407658,
#         0.14819661,  3.74082551, 14.85923756,  1.10761988,  9.87189974,
#         0.68948645,  6.5829032 , 15.5776109 ,  4.36019937,  5.08014195,
#         5.08327002,  6.20589362,  1.05833908,  7.47499254,  5.63181726,
#         9.95956155,  3.35895192,  2.91294113,  2.62987823, -0.02360377,
#         0.23200516, -3.0746308 , 15.8710427 ,  1.68942979, -2.93529483,
#         2.44295095,  1.99167069,  9.8469902 ,  4.58442772,  2.24025455,
#        -2.64933448,  0.2713265 ,  3.98254177,  5.10338252, 10.02603053,
#         5.70354979,  6.52383178,  5.77621602,  2.23175751,  7.6770493 ,
#         7.84729401,  4.66063632,  2.27045178, -0.18793445, -0.97478008,
# ...

# %%
r2_score(y_test,y_preds)
# Out:
# 0.8809887607371324

# %%
R_squared
# Out:
# 0.9129890581379756

# %%
Adjusted_R_squared
# Out:
# 1.3687606583676273

# %%
MSE=mean_squared_error(y_test,y_preds)

# %%
MSE
# Out:
# 2.480468071099706
